# %%
import tensorflow as tf
print(tf.__version__)
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5058/3279949229.py in <module>
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__)
#       3 print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# import zipfile

# zip_ref = zipfile.ZipFile("archive.zip")
# zip_ref.extractall()
# zip_ref.close

# %%
train_dir = "dog_breed_data/train"
test_dir = "dog_breed_data/test"

# %%
import os
import random
class_names = os.listdir(train_dir)
random_img_label = random.choice(class_names)
random_img_path = f"{train_dir}/{random_img_label}"
random_img = random.choice(os.listdir(random_img_path))
img = plt.imread(f"{random_img_path}/{random_img}")
plt.imshow(img)
plt.title(random_img_label)
plt.axis(False)
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
from tensorflow.keras.preproccesing import image_dataset_from_directory

train_data = image_dataset_from_directory(train_dir,
            image_size = (384,384),
            label_mode='categorical')

test_data = image_dataset_from_directory(test_dir,
            image_size =(384,384),
            label_mode = 'categorical')
# Out:
# Found 8177 files belonging to 120 classes.
# Found 2045 files belonging to 120 classes.

# %%
for image,label in train_data:
    plt.imshow(image[0]/255)
    plt.title(class_names[np.argmax(label[0])])
    plt.axis(False)
    print(image[0].shape)
    break
# Out:
# (384, 384, 3)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
from tensorflow.keras import layers

data_augmentation = tf.keras.Sequential([
                  layers.RandomFlip('horizontal'),
                  layers.RandomZoom(0.2),
                  layers.RandomRotation(0.2),
                  layers.RandomHeight(0.2),
                  layers.RandomWidth(0.2),
                  ])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 from tensorflow.keras import layers
#       3 data_augmentation = tf.keras.Sequential([
# ----> 4                   layers.RandomFlip('horizontal'),
#       5                   layers.RandomZoom(0.2),
#       6                   layers.RandomRotation(0.2),
#       7                   layers.RandomHeight(0.2),
#       8                   layers.RandomWidth(0.2),
#       9                   ])
#
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'RandomFlip'

# %%
base_model = tf.keras.applications.EfficientNetB3(include_top=False)
base_model.trainable = False

inputs = layers.Input(shape=(384,384,3))
x  = data_augmentation(inputs)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(120,activation='softmax')(x)

model_1 = tf.keras.Model(inputs,outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model_1.compile(loss = tf.keras.losses.CategoricalCrossentropy(),
                optimizer = tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

# %%
chkpt_dir = "Model_chpkpt/first_chkpt.weights.h5"
model_check = tf.keras.callbacks.ModelCheckpoint(chkpt_dir,
                                                 save_best_only = True,
                                                 save_weights_only = True)

# %%
history_1 = model_1.fit(train_data,
                        epochs = 5,
                        validation_data = test_data,
                        validation_steps = int(0.25*len(test_data)),
                        callbacks = [model_check])
# Out:
# Epoch 1/5
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 196ms/step - accuracy: 0.7752 - loss: 0.7900 - val_accuracy: 0.8594 - val_loss: 0.4478
# Epoch 2/5
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 51s 197ms/step - accuracy: 0.7990 - loss: 0.7146 - val_accuracy: 0.8691 - val_loss: 0.4357
# Epoch 3/5
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 142s 433ms/step - accuracy: 0.8147 - loss: 0.6438 - val_accuracy: 0.8594 - val_loss: 0.4188
# Epoch 4/5
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 52s 203ms/step - accuracy: 0.8297 - loss: 0.5903 - val_accuracy: 0.8770 - val_loss: 0.4279
# Epoch 5/5
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 78s 190ms/step - accuracy: 0.8344 - loss: 0.5722 - val_accuracy: 0.8887 - val_loss: 0.3873

# %%
base_model.trainable = True
base_model.layers
# Out:
# [<InputLayer name=input_layer, built=True>,
#  <Rescaling name=rescaling, built=True>,
#  <Normalization name=normalization, built=True>,
#  <Rescaling name=rescaling_1, built=True>,
#  <ZeroPadding2D name=stem_conv_pad, built=True>,
#  <Conv2D name=stem_conv, built=True>,
#  <BatchNormalization name=stem_bn, built=True>,
#  <Activation name=stem_activation, built=True>,
#  <DepthwiseConv2D name=block1a_dwconv, built=True>,
#  <BatchNormalization name=block1a_bn, built=True>,
#  <Activation name=block1a_activation, built=True>,
#  <GlobalAveragePooling2D name=block1a_se_squeeze, built=True>,
#  <Reshape name=block1a_se_reshape, built=True>,
#  <Conv2D name=block1a_se_reduce, built=True>,
#  <Conv2D name=block1a_se_expand, built=True>,
#  <Multiply name=block1a_se_excite, built=True>,
#  <Conv2D name=block1a_project_conv, built=True>,
#  <BatchNormalization name=block1a_project_bn, built=True>,
#  <DepthwiseConv2D name=block1b_dwconv, built=True>,
#  <BatchNormalization name=block1b_bn, built=True>,
#  <Activation name=block1b_activation, built=True>,
#  <GlobalAveragePooling2D name=block1b_se_squeeze, built=True>,
#  <Reshape name=block1b_se_reshape, built=True>,
#  <Conv2D name=block1b_se_reduce, built=True>,
#  <Conv2D name=block1b_se_expand, built=True>,
#  <Multiply name=block1b_se_excite, built=True>,
#  <Conv2D name=block1b_project_conv, built=True>,
#  <BatchNormalization name=block1b_project_bn, built=True>,
#  <Dropout name=block1b_drop, built=True>,
#  <Add name=block1b_add, built=True>,
#  <Conv2D name=block2a_expand_conv, built=True>,
#  <BatchNormalization name=block2a_expand_bn, built=True>,
#  <Activation name=block2a_expand_activation, built=True>,
#  <ZeroPadding2D name=block2a_dwconv_pad, built=True>,
#  <DepthwiseConv2D name=block2a_dwconv, built=True>,
#  <BatchNormalization name=block2a_bn, built=True>,
#  <Activation name=block2a_activation, built=True>,
#  <GlobalAveragePooling2D name=block2a_se_squeeze, built=True>,
#  <Reshape name=block2a_se_reshape, built=True>,
#  <Conv2D name=block2a_se_reduce, built=True>,
#  <Conv2D name=block2a_se_expand, built=True>,
#  <Multiply name=block2a_se_excite, built=True>,
#  <Conv2D name=block2a_project_conv, built=True>,
#  <BatchNormalization name=block2a_project_bn, built=True>,
#  <Conv2D name=block2b_expand_conv, built=True>,
#  <BatchNormalization name=block2b_expand_bn, built=True>,
#  <Activation name=block2b_expand_activation, built=True>,
#  <DepthwiseConv2D name=block2b_dwconv, built=True>,
#  <BatchNormalization name=block2b_bn, built=True>,
#  <Activation name=block2b_activation, built=True>,
#  <GlobalAveragePooling2D name=block2b_se_squeeze, built=True>,
#  <Reshape name=block2b_se_reshape, built=True>,
#  <Conv2D name=block2b_se_reduce, built=True>,
#  <Conv2D name=block2b_se_expand, built=True>,
#  <Multiply name=block2b_se_excite, built=True>,
#  <Conv2D name=block2b_project_conv, built=True>,
#  <BatchNormalization name=block2b_project_bn, built=True>,
#  <Dropout name=block2b_drop, built=True>,
#  <Add name=block2b_add, built=True>,
#  <Conv2D name=block2c_expand_conv, built=True>,
#  <BatchNormalization name=block2c_expand_bn, built=True>,
#  <Activation name=block2c_expand_activation, built=True>,
#  <DepthwiseConv2D name=block2c_dwconv, built=True>,
#  <BatchNormalization name=block2c_bn, built=True>,
#  <Activation name=block2c_activation, built=True>,
#  <GlobalAveragePooling2D name=block2c_se_squeeze, built=True>,
#  <Reshape name=block2c_se_reshape, built=True>,
#  <Conv2D name=block2c_se_reduce, built=True>,
#  <Conv2D name=block2c_se_expand, built=True>,
#  <Multiply name=block2c_se_excite, built=True>,
#  <Conv2D name=block2c_project_conv, built=True>,
#  <BatchNormalization name=block2c_project_bn, built=True>,
#  <Dropout name=block2c_drop, built=True>,
#  <Add name=block2c_add, built=True>,
#  <Conv2D name=block3a_expand_conv, built=True>,
#  <BatchNormalization name=block3a_expand_bn, built=True>,
#  <Activation name=block3a_expand_activation, built=True>,
#  <ZeroPadding2D name=block3a_dwconv_pad, built=True>,
#  <DepthwiseConv2D name=block3a_dwconv, built=True>,
#  <BatchNormalization name=block3a_bn, built=True>,
#  <Activation name=block3a_activation, built=True>,
#  <GlobalAveragePooling2D name=block3a_se_squeeze, built=True>,
#  <Reshape name=block3a_se_reshape, built=True>,
#  <Conv2D name=block3a_se_reduce, built=True>,
#  <Conv2D name=block3a_se_expand, built=True>,
#  <Multiply name=block3a_se_excite, built=True>,
#  <Conv2D name=block3a_project_conv, built=True>,
#  <BatchNormalization name=block3a_project_bn, built=True>,
#  <Conv2D name=block3b_expand_conv, built=True>,
#  <BatchNormalization name=block3b_expand_bn, built=True>,
#  <Activation name=block3b_expand_activation, built=True>,
#  <DepthwiseConv2D name=block3b_dwconv, built=True>,
#  <BatchNormalization name=block3b_bn, built=True>,
#  <Activation name=block3b_activation, built=True>,
#  <GlobalAveragePooling2D name=block3b_se_squeeze, built=True>,
#  <Reshape name=block3b_se_reshape, built=True>,
#  <Conv2D name=block3b_se_reduce, built=True>,
#  <Conv2D name=block3b_se_expand, built=True>,
#  <Multiply name=block3b_se_excite, built=True>,
#  <Conv2D name=block3b_project_conv, built=True>,
#  <BatchNormalization name=block3b_project_bn, built=True>,
#  <Dropout name=block3b_drop, built=True>,
#  <Add name=block3b_add, built=True>,
#  <Conv2D name=block3c_expand_conv, built=True>,
#  <BatchNormalization name=block3c_expand_bn, built=True>,
#  <Activation name=block3c_expand_activation, built=True>,
#  <DepthwiseConv2D name=block3c_dwconv, built=True>,
#  <BatchNormalization name=block3c_bn, built=True>,
#  <Activation name=block3c_activation, built=True>,
#  <GlobalAveragePooling2D name=block3c_se_squeeze, built=True>,
#  <Reshape name=block3c_se_reshape, built=True>,
#  <Conv2D name=block3c_se_reduce, built=True>,
#  <Conv2D name=block3c_se_expand, built=True>,
#  <Multiply name=block3c_se_excite, built=True>,
#  <Conv2D name=block3c_project_conv, built=True>,
#  <BatchNormalization name=block3c_project_bn, built=True>,
#  <Dropout name=block3c_drop, built=True>,
#  <Add name=block3c_add, built=True>,
#  <Conv2D name=block4a_expand_conv, built=True>,
#  <BatchNormalization name=block4a_expand_bn, built=True>,
#  <Activation name=block4a_expand_activation, built=True>,
#  <ZeroPadding2D name=block4a_dwconv_pad, built=True>,
#  <DepthwiseConv2D name=block4a_dwconv, built=True>,
#  <BatchNormalization name=block4a_bn, built=True>,
#  <Activation name=block4a_activation, built=True>,
#  <GlobalAveragePooling2D name=block4a_se_squeeze, built=True>,
#  <Reshape name=block4a_se_reshape, built=True>,
#  <Conv2D name=block4a_se_reduce, built=True>,
#  <Conv2D name=block4a_se_expand, built=True>,
#  <Multiply name=block4a_se_excite, built=True>,
#  <Conv2D name=block4a_project_conv, built=True>,
#  <BatchNormalization name=block4a_project_bn, built=True>,
#  <Conv2D name=block4b_expand_conv, built=True>,
#  <BatchNormalization name=block4b_expand_bn, built=True>,
#  <Activation name=block4b_expand_activation, built=True>,
#  <DepthwiseConv2D name=block4b_dwconv, built=True>,
#  <BatchNormalization name=block4b_bn, built=True>,
#  <Activation name=block4b_activation, built=True>,
#  <GlobalAveragePooling2D name=block4b_se_squeeze, built=True>,
#  <Reshape name=block4b_se_reshape, built=True>,
#  <Conv2D name=block4b_se_reduce, built=True>,
#  <Conv2D name=block4b_se_expand, built=True>,
#  <Multiply name=block4b_se_excite, built=True>,
#  <Conv2D name=block4b_project_conv, built=True>,
#  <BatchNormalization name=block4b_project_bn, built=True>,
#  <Dropout name=block4b_drop, built=True>,
#  <Add name=block4b_add, built=True>,
#  <Conv2D name=block4c_expand_conv, built=True>,
#  <BatchNormalization name=block4c_expand_bn, built=True>,
#  <Activation name=block4c_expand_activation, built=True>,
#  <DepthwiseConv2D name=block4c_dwconv, built=True>,
#  <BatchNormalization name=block4c_bn, built=True>,
#  <Activation name=block4c_activation, built=True>,
#  <GlobalAveragePooling2D name=block4c_se_squeeze, built=True>,
#  <Reshape name=block4c_se_reshape, built=True>,
#  <Conv2D name=block4c_se_reduce, built=True>,
#  <Conv2D name=block4c_se_expand, built=True>,
#  <Multiply name=block4c_se_excite, built=True>,
#  <Conv2D name=block4c_project_conv, built=True>,
#  <BatchNormalization name=block4c_project_bn, built=True>,
#  <Dropout name=block4c_drop, built=True>,
#  <Add name=block4c_add, built=True>,
#  <Conv2D name=block4d_expand_conv, built=True>,
#  <BatchNormalization name=block4d_expand_bn, built=True>,
#  <Activation name=block4d_expand_activation, built=True>,
#  <DepthwiseConv2D name=block4d_dwconv, built=True>,
#  <BatchNormalization name=block4d_bn, built=True>,
#  <Activation name=block4d_activation, built=True>,
#  <GlobalAveragePooling2D name=block4d_se_squeeze, built=True>,
#  <Reshape name=block4d_se_reshape, built=True>,
#  <Conv2D name=block4d_se_reduce, built=True>,
#  <Conv2D name=block4d_se_expand, built=True>,
#  <Multiply name=block4d_se_excite, built=True>,
#  <Conv2D name=block4d_project_conv, built=True>,
#  <BatchNormalization name=block4d_project_bn, built=True>,
#  <Dropout name=block4d_drop, built=True>,
#  <Add name=block4d_add, built=True>,
#  <Conv2D name=block4e_expand_conv, built=True>,
#  <BatchNormalization name=block4e_expand_bn, built=True>,
#  <Activation name=block4e_expand_activation, built=True>,
#  <DepthwiseConv2D name=block4e_dwconv, built=True>,
#  <BatchNormalization name=block4e_bn, built=True>,
#  <Activation name=block4e_activation, built=True>,
#  <GlobalAveragePooling2D name=block4e_se_squeeze, built=True>,
#  <Reshape name=block4e_se_reshape, built=True>,
#  <Conv2D name=block4e_se_reduce, built=True>,
#  <Conv2D name=block4e_se_expand, built=True>,
#  <Multiply name=block4e_se_excite, built=True>,
#  <Conv2D name=block4e_project_conv, built=True>,
#  <BatchNormalization name=block4e_project_bn, built=True>,
#  <Dropout name=block4e_drop, built=True>,
#  <Add name=block4e_add, built=True>,
#  <Conv2D name=block5a_expand_conv, built=True>,
#  <BatchNormalization name=block5a_expand_bn, built=True>,
#  <Activation name=block5a_expand_activation, built=True>,
#  <DepthwiseConv2D name=block5a_dwconv, built=True>,
#  <BatchNormalization name=block5a_bn, built=True>,
#  <Activation name=block5a_activation, built=True>,
#  <GlobalAveragePooling2D name=block5a_se_squeeze, built=True>,
#  <Reshape name=block5a_se_reshape, built=True>,
#  <Conv2D name=block5a_se_reduce, built=True>,
#  <Conv2D name=block5a_se_expand, built=True>,
#  <Multiply name=block5a_se_excite, built=True>,
#  <Conv2D name=block5a_project_conv, built=True>,
#  <BatchNormalization name=block5a_project_bn, built=True>,
#  <Conv2D name=block5b_expand_conv, built=True>,
#  <BatchNormalization name=block5b_expand_bn, built=True>,
#  <Activation name=block5b_expand_activation, built=True>,
#  <DepthwiseConv2D name=block5b_dwconv, built=True>,
#  <BatchNormalization name=block5b_bn, built=True>,
#  <Activation name=block5b_activation, built=True>,
#  <GlobalAveragePooling2D name=block5b_se_squeeze, built=True>,
#  <Reshape name=block5b_se_reshape, built=True>,
#  <Conv2D name=block5b_se_reduce, built=True>,
#  <Conv2D name=block5b_se_expand, built=True>,
#  <Multiply name=block5b_se_excite, built=True>,
#  <Conv2D name=block5b_project_conv, built=True>,
#  <BatchNormalization name=block5b_project_bn, built=True>,
#  <Dropout name=block5b_drop, built=True>,
#  <Add name=block5b_add, built=True>,
#  <Conv2D name=block5c_expand_conv, built=True>,
#  <BatchNormalization name=block5c_expand_bn, built=True>,
#  <Activation name=block5c_expand_activation, built=True>,
#  <DepthwiseConv2D name=block5c_dwconv, built=True>,
#  <BatchNormalization name=block5c_bn, built=True>,
#  <Activation name=block5c_activation, built=True>,
#  <GlobalAveragePooling2D name=block5c_se_squeeze, built=True>,
#  <Reshape name=block5c_se_reshape, built=True>,
#  <Conv2D name=block5c_se_reduce, built=True>,
#  <Conv2D name=block5c_se_expand, built=True>,
#  <Multiply name=block5c_se_excite, built=True>,
#  <Conv2D name=block5c_project_conv, built=True>,
#  <BatchNormalization name=block5c_project_bn, built=True>,
#  <Dropout name=block5c_drop, built=True>,
#  <Add name=block5c_add, built=True>,
#  <Conv2D name=block5d_expand_conv, built=True>,
#  <BatchNormalization name=block5d_expand_bn, built=True>,
#  <Activation name=block5d_expand_activation, built=True>,
#  <DepthwiseConv2D name=block5d_dwconv, built=True>,
#  <BatchNormalization name=block5d_bn, built=True>,
#  <Activation name=block5d_activation, built=True>,
#  <GlobalAveragePooling2D name=block5d_se_squeeze, built=True>,
#  <Reshape name=block5d_se_reshape, built=True>,
#  <Conv2D name=block5d_se_reduce, built=True>,
#  <Conv2D name=block5d_se_expand, built=True>,
#  <Multiply name=block5d_se_excite, built=True>,
#  <Conv2D name=block5d_project_conv, built=True>,
#  <BatchNormalization name=block5d_project_bn, built=True>,
#  <Dropout name=block5d_drop, built=True>,
#  <Add name=block5d_add, built=True>,
#  <Conv2D name=block5e_expand_conv, built=True>,
#  <BatchNormalization name=block5e_expand_bn, built=True>,
#  <Activation name=block5e_expand_activation, built=True>,
#  <DepthwiseConv2D name=block5e_dwconv, built=True>,
#  <BatchNormalization name=block5e_bn, built=True>,
#  <Activation name=block5e_activation, built=True>,
#  <GlobalAveragePooling2D name=block5e_se_squeeze, built=True>,
#  <Reshape name=block5e_se_reshape, built=True>,
#  <Conv2D name=block5e_se_reduce, built=True>,
#  <Conv2D name=block5e_se_expand, built=True>,
#  <Multiply name=block5e_se_excite, built=True>,
#  <Conv2D name=block5e_project_conv, built=True>,
#  <BatchNormalization name=block5e_project_bn, built=True>,
#  <Dropout name=block5e_drop, built=True>,
#  <Add name=block5e_add, built=True>,
#  <Conv2D name=block6a_expand_conv, built=True>,
#  <BatchNormalization name=block6a_expand_bn, built=True>,
#  <Activation name=block6a_expand_activation, built=True>,
#  <ZeroPadding2D name=block6a_dwconv_pad, built=True>,
#  <DepthwiseConv2D name=block6a_dwconv, built=True>,
#  <BatchNormalization name=block6a_bn, built=True>,
#  <Activation name=block6a_activation, built=True>,
#  <GlobalAveragePooling2D name=block6a_se_squeeze, built=True>,
#  <Reshape name=block6a_se_reshape, built=True>,
#  <Conv2D name=block6a_se_reduce, built=True>,
#  <Conv2D name=block6a_se_expand, built=True>,
#  <Multiply name=block6a_se_excite, built=True>,
#  <Conv2D name=block6a_project_conv, built=True>,
#  <BatchNormalization name=block6a_project_bn, built=True>,
#  <Conv2D name=block6b_expand_conv, built=True>,
#  <BatchNormalization name=block6b_expand_bn, built=True>,
#  <Activation name=block6b_expand_activation, built=True>,
#  <DepthwiseConv2D name=block6b_dwconv, built=True>,
#  <BatchNormalization name=block6b_bn, built=True>,
#  <Activation name=block6b_activation, built=True>,
#  <GlobalAveragePooling2D name=block6b_se_squeeze, built=True>,
#  <Reshape name=block6b_se_reshape, built=True>,
#  <Conv2D name=block6b_se_reduce, built=True>,
#  <Conv2D name=block6b_se_expand, built=True>,
#  <Multiply name=block6b_se_excite, built=True>,
#  <Conv2D name=block6b_project_conv, built=True>,
#  <BatchNormalization name=block6b_project_bn, built=True>,
#  <Dropout name=block6b_drop, built=True>,
#  <Add name=block6b_add, built=True>,
#  <Conv2D name=block6c_expand_conv, built=True>,
#  <BatchNormalization name=block6c_expand_bn, built=True>,
#  <Activation name=block6c_expand_activation, built=True>,
#  <DepthwiseConv2D name=block6c_dwconv, built=True>,
#  <BatchNormalization name=block6c_bn, built=True>,
#  <Activation name=block6c_activation, built=True>,
#  <GlobalAveragePooling2D name=block6c_se_squeeze, built=True>,
#  <Reshape name=block6c_se_reshape, built=True>,
#  <Conv2D name=block6c_se_reduce, built=True>,
#  <Conv2D name=block6c_se_expand, built=True>,
#  <Multiply name=block6c_se_excite, built=True>,
#  <Conv2D name=block6c_project_conv, built=True>,
#  <BatchNormalization name=block6c_project_bn, built=True>,
#  <Dropout name=block6c_drop, built=True>,
#  <Add name=block6c_add, built=True>,
#  <Conv2D name=block6d_expand_conv, built=True>,
#  <BatchNormalization name=block6d_expand_bn, built=True>,
#  <Activation name=block6d_expand_activation, built=True>,
#  <DepthwiseConv2D name=block6d_dwconv, built=True>,
#  <BatchNormalization name=block6d_bn, built=True>,
#  <Activation name=block6d_activation, built=True>,
#  <GlobalAveragePooling2D name=block6d_se_squeeze, built=True>,
#  <Reshape name=block6d_se_reshape, built=True>,
#  <Conv2D name=block6d_se_reduce, built=True>,
#  <Conv2D name=block6d_se_expand, built=True>,
#  <Multiply name=block6d_se_excite, built=True>,
#  <Conv2D name=block6d_project_conv, built=True>,
#  <BatchNormalization name=block6d_project_bn, built=True>,
#  <Dropout name=block6d_drop, built=True>,
#  <Add name=block6d_add, built=True>,
#  <Conv2D name=block6e_expand_conv, built=True>,
#  <BatchNormalization name=block6e_expand_bn, built=True>,
#  <Activation name=block6e_expand_activation, built=True>,
#  <DepthwiseConv2D name=block6e_dwconv, built=True>,
#  <BatchNormalization name=block6e_bn, built=True>,
#  <Activation name=block6e_activation, built=True>,
#  <GlobalAveragePooling2D name=block6e_se_squeeze, built=True>,
#  <Reshape name=block6e_se_reshape, built=True>,
#  <Conv2D name=block6e_se_reduce, built=True>,
#  <Conv2D name=block6e_se_expand, built=True>,
#  <Multiply name=block6e_se_excite, built=True>,
#  <Conv2D name=block6e_project_conv, built=True>,
#  <BatchNormalization name=block6e_project_bn, built=True>,
#  <Dropout name=block6e_drop, built=True>,
#  <Add name=block6e_add, built=True>,
#  <Conv2D name=block6f_expand_conv, built=True>,
#  <BatchNormalization name=block6f_expand_bn, built=True>,
#  <Activation name=block6f_expand_activation, built=True>,
#  <DepthwiseConv2D name=block6f_dwconv, built=True>,
#  <BatchNormalization name=block6f_bn, built=True>,
#  <Activation name=block6f_activation, built=True>,
#  <GlobalAveragePooling2D name=block6f_se_squeeze, built=True>,
#  <Reshape name=block6f_se_reshape, built=True>,
#  <Conv2D name=block6f_se_reduce, built=True>,
#  <Conv2D name=block6f_se_expand, built=True>,
#  <Multiply name=block6f_se_excite, built=True>,
#  <Conv2D name=block6f_project_conv, built=True>,
#  <BatchNormalization name=block6f_project_bn, built=True>,
#  <Dropout name=block6f_drop, built=True>,
#  <Add name=block6f_add, built=True>,
#  <Conv2D name=block7a_expand_conv, built=True>,
#  <BatchNormalization name=block7a_expand_bn, built=True>,
#  <Activation name=block7a_expand_activation, built=True>,
#  <DepthwiseConv2D name=block7a_dwconv, built=True>,
#  <BatchNormalization name=block7a_bn, built=True>,
#  <Activation name=block7a_activation, built=True>,
#  <GlobalAveragePooling2D name=block7a_se_squeeze, built=True>,
#  <Reshape name=block7a_se_reshape, built=True>,
#  <Conv2D name=block7a_se_reduce, built=True>,
#  <Conv2D name=block7a_se_expand, built=True>,
#  <Multiply name=block7a_se_excite, built=True>,
#  <Conv2D name=block7a_project_conv, built=True>,
#  <BatchNormalization name=block7a_project_bn, built=True>,
#  <Conv2D name=block7b_expand_conv, built=True>,
#  <BatchNormalization name=block7b_expand_bn, built=True>,
#  <Activation name=block7b_expand_activation, built=True>,
#  <DepthwiseConv2D name=block7b_dwconv, built=True>,
#  <BatchNormalization name=block7b_bn, built=True>,
#  <Activation name=block7b_activation, built=True>,
#  <GlobalAveragePooling2D name=block7b_se_squeeze, built=True>,
#  <Reshape name=block7b_se_reshape, built=True>,
#  <Conv2D name=block7b_se_reduce, built=True>,
#  <Conv2D name=block7b_se_expand, built=True>,
#  <Multiply name=block7b_se_excite, built=True>,
#  <Conv2D name=block7b_project_conv, built=True>,
#  <BatchNormalization name=block7b_project_bn, built=True>,
#  <Dropout name=block7b_drop, built=True>,
#  <Add name=block7b_add, built=True>,
#  <Conv2D name=top_conv, built=True>,
#  <BatchNormalization name=top_bn, built=True>,
#  <Activation name=top_activation, built=True>]

# %%
for layers in base_model.layers[:-5]:
    layers.trainable = False

# %%
for layer in base_model.layers:
    print(f"Layer: {layer.name}, Trainable: {layer.trainable}")
# Out:
# Layer: input_layer, Trainable: False
# Layer: rescaling, Trainable: False
# Layer: normalization, Trainable: False
# Layer: rescaling_1, Trainable: False
# Layer: stem_conv_pad, Trainable: False
# Layer: stem_conv, Trainable: False
# Layer: stem_bn, Trainable: False
# Layer: stem_activation, Trainable: False
# Layer: block1a_dwconv, Trainable: False
# Layer: block1a_bn, Trainable: False
# Layer: block1a_activation, Trainable: False
# Layer: block1a_se_squeeze, Trainable: False
# Layer: block1a_se_reshape, Trainable: False
# Layer: block1a_se_reduce, Trainable: False
# Layer: block1a_se_expand, Trainable: False
# Layer: block1a_se_excite, Trainable: False
# Layer: block1a_project_conv, Trainable: False
# Layer: block1a_project_bn, Trainable: False
# Layer: block1b_dwconv, Trainable: False
# Layer: block1b_bn, Trainable: False
# Layer: block1b_activation, Trainable: False
# Layer: block1b_se_squeeze, Trainable: False
# Layer: block1b_se_reshape, Trainable: False
# Layer: block1b_se_reduce, Trainable: False
# Layer: block1b_se_expand, Trainable: False
# Layer: block1b_se_excite, Trainable: False
# Layer: block1b_project_conv, Trainable: False
# Layer: block1b_project_bn, Trainable: False
# Layer: block1b_drop, Trainable: False
# Layer: block1b_add, Trainable: False
# Layer: block2a_expand_conv, Trainable: False
# Layer: block2a_expand_bn, Trainable: False
# Layer: block2a_expand_activation, Trainable: False
# Layer: block2a_dwconv_pad, Trainable: False
# Layer: block2a_dwconv, Trainable: False
# Layer: block2a_bn, Trainable: False
# Layer: block2a_activation, Trainable: False
# Layer: block2a_se_squeeze, Trainable: False
# Layer: block2a_se_reshape, Trainable: False
# Layer: block2a_se_reduce, Trainable: False
# Layer: block2a_se_expand, Trainable: False
# Layer: block2a_se_excite, Trainable: False
# Layer: block2a_project_conv, Trainable: False
# Layer: block2a_project_bn, Trainable: False
# Layer: block2b_expand_conv, Trainable: False
# Layer: block2b_expand_bn, Trainable: False
# Layer: block2b_expand_activation, Trainable: False
# Layer: block2b_dwconv, Trainable: False
# Layer: block2b_bn, Trainable: False
# Layer: block2b_activation, Trainable: False
# Layer: block2b_se_squeeze, Trainable: False
# Layer: block2b_se_reshape, Trainable: False
# Layer: block2b_se_reduce, Trainable: False
# Layer: block2b_se_expand, Trainable: False
# Layer: block2b_se_excite, Trainable: False
# Layer: block2b_project_conv, Trainable: False
# Layer: block2b_project_bn, Trainable: False
# Layer: block2b_drop, Trainable: False
# Layer: block2b_add, Trainable: False
# Layer: block2c_expand_conv, Trainable: False
# Layer: block2c_expand_bn, Trainable: False
# Layer: block2c_expand_activation, Trainable: False
# Layer: block2c_dwconv, Trainable: False
# Layer: block2c_bn, Trainable: False
# Layer: block2c_activation, Trainable: False
# Layer: block2c_se_squeeze, Trainable: False
# Layer: block2c_se_reshape, Trainable: False
# Layer: block2c_se_reduce, Trainable: False
# Layer: block2c_se_expand, Trainable: False
# Layer: block2c_se_excite, Trainable: False
# Layer: block2c_project_conv, Trainable: False
# Layer: block2c_project_bn, Trainable: False
# Layer: block2c_drop, Trainable: False
# Layer: block2c_add, Trainable: False
# Layer: block3a_expand_conv, Trainable: False
# Layer: block3a_expand_bn, Trainable: False
# Layer: block3a_expand_activation, Trainable: False
# Layer: block3a_dwconv_pad, Trainable: False
# Layer: block3a_dwconv, Trainable: False
# Layer: block3a_bn, Trainable: False
# Layer: block3a_activation, Trainable: False
# Layer: block3a_se_squeeze, Trainable: False
# Layer: block3a_se_reshape, Trainable: False
# Layer: block3a_se_reduce, Trainable: False
# Layer: block3a_se_expand, Trainable: False
# Layer: block3a_se_excite, Trainable: False
# Layer: block3a_project_conv, Trainable: False
# Layer: block3a_project_bn, Trainable: False
# Layer: block3b_expand_conv, Trainable: False
# Layer: block3b_expand_bn, Trainable: False
# Layer: block3b_expand_activation, Trainable: False
# Layer: block3b_dwconv, Trainable: False
# Layer: block3b_bn, Trainable: False
# Layer: block3b_activation, Trainable: False
# Layer: block3b_se_squeeze, Trainable: False
# Layer: block3b_se_reshape, Trainable: False
# Layer: block3b_se_reduce, Trainable: False
# Layer: block3b_se_expand, Trainable: False
# Layer: block3b_se_excite, Trainable: False
# Layer: block3b_project_conv, Trainable: False
# Layer: block3b_project_bn, Trainable: False
# Layer: block3b_drop, Trainable: False
# Layer: block3b_add, Trainable: False
# Layer: block3c_expand_conv, Trainable: False
# Layer: block3c_expand_bn, Trainable: False
# Layer: block3c_expand_activation, Trainable: False
# Layer: block3c_dwconv, Trainable: False
# Layer: block3c_bn, Trainable: False
# Layer: block3c_activation, Trainable: False
# Layer: block3c_se_squeeze, Trainable: False
# Layer: block3c_se_reshape, Trainable: False
# Layer: block3c_se_reduce, Trainable: False
# Layer: block3c_se_expand, Trainable: False
# Layer: block3c_se_excite, Trainable: False
# Layer: block3c_project_conv, Trainable: False
# Layer: block3c_project_bn, Trainable: False
# Layer: block3c_drop, Trainable: False
# Layer: block3c_add, Trainable: False
# Layer: block4a_expand_conv, Trainable: False
# Layer: block4a_expand_bn, Trainable: False
# Layer: block4a_expand_activation, Trainable: False
# Layer: block4a_dwconv_pad, Trainable: False
# Layer: block4a_dwconv, Trainable: False
# Layer: block4a_bn, Trainable: False
# Layer: block4a_activation, Trainable: False
# Layer: block4a_se_squeeze, Trainable: False
# Layer: block4a_se_reshape, Trainable: False
# Layer: block4a_se_reduce, Trainable: False
# Layer: block4a_se_expand, Trainable: False
# Layer: block4a_se_excite, Trainable: False
# Layer: block4a_project_conv, Trainable: False
# Layer: block4a_project_bn, Trainable: False
# Layer: block4b_expand_conv, Trainable: False
# Layer: block4b_expand_bn, Trainable: False
# Layer: block4b_expand_activation, Trainable: False
# Layer: block4b_dwconv, Trainable: False
# Layer: block4b_bn, Trainable: False
# Layer: block4b_activation, Trainable: False
# Layer: block4b_se_squeeze, Trainable: False
# Layer: block4b_se_reshape, Trainable: False
# Layer: block4b_se_reduce, Trainable: False
# Layer: block4b_se_expand, Trainable: False
# Layer: block4b_se_excite, Trainable: False
# Layer: block4b_project_conv, Trainable: False
# Layer: block4b_project_bn, Trainable: False
# Layer: block4b_drop, Trainable: False
# Layer: block4b_add, Trainable: False
# Layer: block4c_expand_conv, Trainable: False
# Layer: block4c_expand_bn, Trainable: False
# Layer: block4c_expand_activation, Trainable: False
# Layer: block4c_dwconv, Trainable: False
# Layer: block4c_bn, Trainable: False
# Layer: block4c_activation, Trainable: False
# Layer: block4c_se_squeeze, Trainable: False
# Layer: block4c_se_reshape, Trainable: False
# Layer: block4c_se_reduce, Trainable: False
# Layer: block4c_se_expand, Trainable: False
# Layer: block4c_se_excite, Trainable: False
# Layer: block4c_project_conv, Trainable: False
# Layer: block4c_project_bn, Trainable: False
# Layer: block4c_drop, Trainable: False
# Layer: block4c_add, Trainable: False
# Layer: block4d_expand_conv, Trainable: False
# Layer: block4d_expand_bn, Trainable: False
# Layer: block4d_expand_activation, Trainable: False
# Layer: block4d_dwconv, Trainable: False
# Layer: block4d_bn, Trainable: False
# Layer: block4d_activation, Trainable: False
# Layer: block4d_se_squeeze, Trainable: False
# Layer: block4d_se_reshape, Trainable: False
# Layer: block4d_se_reduce, Trainable: False
# Layer: block4d_se_expand, Trainable: False
# Layer: block4d_se_excite, Trainable: False
# Layer: block4d_project_conv, Trainable: False
# Layer: block4d_project_bn, Trainable: False
# Layer: block4d_drop, Trainable: False
# Layer: block4d_add, Trainable: False
# Layer: block4e_expand_conv, Trainable: False
# Layer: block4e_expand_bn, Trainable: False
# Layer: block4e_expand_activation, Trainable: False
# Layer: block4e_dwconv, Trainable: False
# Layer: block4e_bn, Trainable: False
# Layer: block4e_activation, Trainable: False
# Layer: block4e_se_squeeze, Trainable: False
# Layer: block4e_se_reshape, Trainable: False
# Layer: block4e_se_reduce, Trainable: False
# Layer: block4e_se_expand, Trainable: False
# Layer: block4e_se_excite, Trainable: False
# Layer: block4e_project_conv, Trainable: False
# Layer: block4e_project_bn, Trainable: False
# Layer: block4e_drop, Trainable: False
# Layer: block4e_add, Trainable: False
# Layer: block5a_expand_conv, Trainable: False
# Layer: block5a_expand_bn, Trainable: False
# Layer: block5a_expand_activation, Trainable: False
# Layer: block5a_dwconv, Trainable: False
# Layer: block5a_bn, Trainable: False
# Layer: block5a_activation, Trainable: False
# Layer: block5a_se_squeeze, Trainable: False
# Layer: block5a_se_reshape, Trainable: False
# Layer: block5a_se_reduce, Trainable: False
# Layer: block5a_se_expand, Trainable: False
# Layer: block5a_se_excite, Trainable: False
# Layer: block5a_project_conv, Trainable: False
# Layer: block5a_project_bn, Trainable: False
# Layer: block5b_expand_conv, Trainable: False
# Layer: block5b_expand_bn, Trainable: False
# Layer: block5b_expand_activation, Trainable: False
# Layer: block5b_dwconv, Trainable: False
# Layer: block5b_bn, Trainable: False
# Layer: block5b_activation, Trainable: False
# Layer: block5b_se_squeeze, Trainable: False
# Layer: block5b_se_reshape, Trainable: False
# Layer: block5b_se_reduce, Trainable: False
# Layer: block5b_se_expand, Trainable: False
# Layer: block5b_se_excite, Trainable: False
# Layer: block5b_project_conv, Trainable: False
# Layer: block5b_project_bn, Trainable: False
# Layer: block5b_drop, Trainable: False
# Layer: block5b_add, Trainable: False
# Layer: block5c_expand_conv, Trainable: False
# Layer: block5c_expand_bn, Trainable: False
# Layer: block5c_expand_activation, Trainable: False
# Layer: block5c_dwconv, Trainable: False
# Layer: block5c_bn, Trainable: False
# Layer: block5c_activation, Trainable: False
# Layer: block5c_se_squeeze, Trainable: False
# Layer: block5c_se_reshape, Trainable: False
# Layer: block5c_se_reduce, Trainable: False
# Layer: block5c_se_expand, Trainable: False
# Layer: block5c_se_excite, Trainable: False
# Layer: block5c_project_conv, Trainable: False
# Layer: block5c_project_bn, Trainable: False
# Layer: block5c_drop, Trainable: False
# Layer: block5c_add, Trainable: False
# Layer: block5d_expand_conv, Trainable: False
# Layer: block5d_expand_bn, Trainable: False
# Layer: block5d_expand_activation, Trainable: False
# Layer: block5d_dwconv, Trainable: False
# Layer: block5d_bn, Trainable: False
# Layer: block5d_activation, Trainable: False
# Layer: block5d_se_squeeze, Trainable: False
# Layer: block5d_se_reshape, Trainable: False
# Layer: block5d_se_reduce, Trainable: False
# Layer: block5d_se_expand, Trainable: False
# Layer: block5d_se_excite, Trainable: False
# Layer: block5d_project_conv, Trainable: False
# Layer: block5d_project_bn, Trainable: False
# Layer: block5d_drop, Trainable: False
# Layer: block5d_add, Trainable: False
# Layer: block5e_expand_conv, Trainable: False
# Layer: block5e_expand_bn, Trainable: False
# Layer: block5e_expand_activation, Trainable: False
# Layer: block5e_dwconv, Trainable: False
# Layer: block5e_bn, Trainable: False
# Layer: block5e_activation, Trainable: False
# Layer: block5e_se_squeeze, Trainable: False
# Layer: block5e_se_reshape, Trainable: False
# Layer: block5e_se_reduce, Trainable: False
# Layer: block5e_se_expand, Trainable: False
# Layer: block5e_se_excite, Trainable: False
# Layer: block5e_project_conv, Trainable: False
# Layer: block5e_project_bn, Trainable: False
# Layer: block5e_drop, Trainable: False
# Layer: block5e_add, Trainable: False
# Layer: block6a_expand_conv, Trainable: False
# Layer: block6a_expand_bn, Trainable: False
# Layer: block6a_expand_activation, Trainable: False
# Layer: block6a_dwconv_pad, Trainable: False
# Layer: block6a_dwconv, Trainable: False
# Layer: block6a_bn, Trainable: False
# Layer: block6a_activation, Trainable: False
# Layer: block6a_se_squeeze, Trainable: False
# Layer: block6a_se_reshape, Trainable: False
# Layer: block6a_se_reduce, Trainable: False
# Layer: block6a_se_expand, Trainable: False
# Layer: block6a_se_excite, Trainable: False
# Layer: block6a_project_conv, Trainable: False
# Layer: block6a_project_bn, Trainable: False
# Layer: block6b_expand_conv, Trainable: False
# Layer: block6b_expand_bn, Trainable: False
# Layer: block6b_expand_activation, Trainable: False
# Layer: block6b_dwconv, Trainable: False
# Layer: block6b_bn, Trainable: False
# Layer: block6b_activation, Trainable: False
# Layer: block6b_se_squeeze, Trainable: False
# Layer: block6b_se_reshape, Trainable: False
# Layer: block6b_se_reduce, Trainable: False
# Layer: block6b_se_expand, Trainable: False
# Layer: block6b_se_excite, Trainable: False
# Layer: block6b_project_conv, Trainable: False
# Layer: block6b_project_bn, Trainable: False
# Layer: block6b_drop, Trainable: False
# Layer: block6b_add, Trainable: False
# Layer: block6c_expand_conv, Trainable: False
# Layer: block6c_expand_bn, Trainable: False
# Layer: block6c_expand_activation, Trainable: False
# Layer: block6c_dwconv, Trainable: False
# Layer: block6c_bn, Trainable: False
# Layer: block6c_activation, Trainable: False
# Layer: block6c_se_squeeze, Trainable: False
# Layer: block6c_se_reshape, Trainable: False
# Layer: block6c_se_reduce, Trainable: False
# Layer: block6c_se_expand, Trainable: False
# Layer: block6c_se_excite, Trainable: False
# Layer: block6c_project_conv, Trainable: False
# Layer: block6c_project_bn, Trainable: False
# Layer: block6c_drop, Trainable: False
# Layer: block6c_add, Trainable: False
# Layer: block6d_expand_conv, Trainable: False
# Layer: block6d_expand_bn, Trainable: False
# Layer: block6d_expand_activation, Trainable: False
# Layer: block6d_dwconv, Trainable: False
# Layer: block6d_bn, Trainable: False
# Layer: block6d_activation, Trainable: False
# Layer: block6d_se_squeeze, Trainable: False
# Layer: block6d_se_reshape, Trainable: False
# Layer: block6d_se_reduce, Trainable: False
# Layer: block6d_se_expand, Trainable: False
# Layer: block6d_se_excite, Trainable: False
# Layer: block6d_project_conv, Trainable: False
# Layer: block6d_project_bn, Trainable: False
# Layer: block6d_drop, Trainable: False
# Layer: block6d_add, Trainable: False
# Layer: block6e_expand_conv, Trainable: False
# Layer: block6e_expand_bn, Trainable: False
# Layer: block6e_expand_activation, Trainable: False
# Layer: block6e_dwconv, Trainable: False
# Layer: block6e_bn, Trainable: False
# Layer: block6e_activation, Trainable: False
# Layer: block6e_se_squeeze, Trainable: False
# Layer: block6e_se_reshape, Trainable: False
# Layer: block6e_se_reduce, Trainable: False
# Layer: block6e_se_expand, Trainable: False
# Layer: block6e_se_excite, Trainable: False
# Layer: block6e_project_conv, Trainable: False
# Layer: block6e_project_bn, Trainable: False
# Layer: block6e_drop, Trainable: False
# Layer: block6e_add, Trainable: False
# Layer: block6f_expand_conv, Trainable: False
# Layer: block6f_expand_bn, Trainable: False
# Layer: block6f_expand_activation, Trainable: False
# Layer: block6f_dwconv, Trainable: False
# Layer: block6f_bn, Trainable: False
# Layer: block6f_activation, Trainable: False
# Layer: block6f_se_squeeze, Trainable: False
# Layer: block6f_se_reshape, Trainable: False
# Layer: block6f_se_reduce, Trainable: False
# Layer: block6f_se_expand, Trainable: False
# Layer: block6f_se_excite, Trainable: False
# Layer: block6f_project_conv, Trainable: False
# Layer: block6f_project_bn, Trainable: False
# Layer: block6f_drop, Trainable: False
# Layer: block6f_add, Trainable: False
# Layer: block7a_expand_conv, Trainable: False
# Layer: block7a_expand_bn, Trainable: False
# Layer: block7a_expand_activation, Trainable: False
# Layer: block7a_dwconv, Trainable: False
# Layer: block7a_bn, Trainable: False
# Layer: block7a_activation, Trainable: False
# Layer: block7a_se_squeeze, Trainable: False
# Layer: block7a_se_reshape, Trainable: False
# Layer: block7a_se_reduce, Trainable: False
# Layer: block7a_se_expand, Trainable: False
# Layer: block7a_se_excite, Trainable: False
# Layer: block7a_project_conv, Trainable: False
# Layer: block7a_project_bn, Trainable: False
# Layer: block7b_expand_conv, Trainable: False
# Layer: block7b_expand_bn, Trainable: False
# Layer: block7b_expand_activation, Trainable: False
# Layer: block7b_dwconv, Trainable: False
# Layer: block7b_bn, Trainable: False
# Layer: block7b_activation, Trainable: False
# Layer: block7b_se_squeeze, Trainable: False
# Layer: block7b_se_reshape, Trainable: False
# Layer: block7b_se_reduce, Trainable: False
# Layer: block7b_se_expand, Trainable: False
# Layer: block7b_se_excite, Trainable: False
# Layer: block7b_project_conv, Trainable: False
# Layer: block7b_project_bn, Trainable: False
# Layer: block7b_drop, Trainable: True
# Layer: block7b_add, Trainable: True
# Layer: top_conv, Trainable: True
# Layer: top_bn, Trainable: True
# Layer: top_activation, Trainable: True

# %%
model_1.fit(train_data,
            epochs = 10,
            initial_epoch = history_1.epoch[-1],
            validation_data = test_data,
            validation_steps = int(25*len(test_data)))
# Out:
# Epoch 5/10
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8448 - loss: 0.5385
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 57s 221ms/step - accuracy: 0.8448 - loss: 0.5385 - val_accuracy: 0.8660 - val_loss: 0.4241
# Epoch 6/10
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 53s 207ms/step - accuracy: 0.8556 - loss: 0.4859 - val_accuracy: 0.8689 - val_loss: 0.4207
# Epoch 7/10
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 84s 216ms/step - accuracy: 0.8556 - loss: 0.4871 - val_accuracy: 0.8685 - val_loss: 0.4169
# Epoch 8/10
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - accuracy: 0.8683 - loss: 0.4451 - val_accuracy: 0.8631 - val_loss: 0.4189
# Epoch 9/10
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 52s 204ms/step - accuracy: 0.8668 - loss: 0.4444 - val_accuracy: 0.8655 - val_loss: 0.4204
# Epoch 10/10
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 84s 213ms/step - accuracy: 0.8766 - loss: 0.4042 - val_accuracy: 0.8680 - val_loss: 0.4194

# %%
model_1.save("/content/drive/MyDrive/Dog_Breed_project/model_1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_1.evaluate(test_data)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.8731 - loss: 0.4112
# [0.4194333851337433, 0.8679706454277039]
